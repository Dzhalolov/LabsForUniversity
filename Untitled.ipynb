# %%
import pandas as pd
import mglearn
import numpy as np
import matplotlib.pyplot as plt

pd.options.display.max_columns = 200

from matplotlib import rcParams
rcParams['figure.figsize'] = 14, 12
rcParams['font.size'] = 16
rcParams['axes.labelsize'] = 14
rcParams['xtick.labelsize'] = 13
rcParams['ytick.labelsize'] = 13
rcParams['legend.fontsize'] = 15

import seaborn as sns
sns.set_style("whitegrid")

# %%
figure = plt.figure()

# %%
plt.figure(figsize=(10,5 * 10)) 
for idx in range(10): 
    plt.subplot(10, 1, idx + 1) 
    plt.plot(range(10), color = 'blue', label='Expected') 
    plt.plot(range(10), color = 'red', label='Predicted') 
    plt.legend()

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
plt.scatter(1, 1)
plt.grid(True)

# %%
from math import factorial as fact
def coef(h, y, k):
    b = 0
    for i in range(k+1):
        b += (-1) ** (k-i) * y[i] / (fact(i) * fact(k-i) * h ** k)
    return b


def multiply(i, x, x_new):
    result = 1
    for index in range(i):
        result *= x_new - x[index]
    return result


def newton(x, x_new, n, y):
    P = 0
    h = x[1] - x[0]
    for i in range(n):
        P += coef(h, y, i) * multiply(i, x, x_new)
    return P

# %%
import numpy as np
import matplotlib.pyplot as plt

a = -10
b = 10
n = 8
x = np.linspace(a, b, n)
y = x ** 2
plt.plot(x, y)
print("x: {} \ny: {}".format(x, y))
x_new = 1.5
y_new = newton(x, x_new, n, y)
plt.plot(x_new, y_new, color='green', marker='o', linestyle='dashed')
# Out:
# x: [-10.          -7.14285714  -4.28571429  -1.42857143   1.42857143
#    4.28571429   7.14285714  10.        ]
# y: [100.          51.02040816  18.36734694   2.04081633   2.04081633
#   18.36734694  51.02040816 100.        ]

# %%
def proccesing(x, n, y):
    result = []
    for i in range(len(x)-1): 
        result.append([(x[i]+x[i+1])/2, newton(x, (x[i]+x[i+1])/2, n, y)])
    return result

# %%
x_new = proccesing(x, n, y)

# %%
x_new = np.array(x_new)

# %%
plt.plot(x_new[:, 0], x_new[:, 1])
plt.plot(x, y)

# %%
x_all = list(np.c_[x[:-1], x_new[:, 0]].reshape(-1, ))
x_all.append(x[-1])
y_all = list(np.c_[y[:-1], x_new[:, 1]].reshape(-1, ))
y_all.append(y[-1])

# %%
x_new
# Out:
# array([[-8.57142857e+00,  7.34693878e+01],
#        [-5.71428571e+00,  3.26530612e+01],
#        [-2.85714286e+00,  8.16326531e+00],
#        [ 0.00000000e+00,  1.36421351e-14],
#        [ 2.85714286e+00,  8.16326531e+00],
#        [ 5.71428571e+00,  3.26530612e+01],
#        [ 8.57142857e+00,  7.34693878e+01]])

# %%
plt.plot(x_new[:, 0], x_new[:, 1], label='newton', linestyle='dashed')
plt.plot(x, y, label='initial', linestyle='dashed')
plt.plot(x_all, y_all, label='initial+newton', linestyle='dashed')
plt.legend(loc="upper center")
